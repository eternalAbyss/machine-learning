# %% [markdown]
# # Pandas
# **This notebook conatins code to demonstrate the use of Pandas library**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Importing the data

# %%
df = pd.read_csv('./../datasets/heart-disease.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# ## Data types
# - Pandas has two main data types series and DataFrames
#
# ### Series
# A series is a one dimensional data structure that contains two columns indicating the index number and the value respectively

# %%
series = pd.Series(['Apple','Banana','Carrot','Date'])
series
# Out:
# 0     Apple
# 1    Banana
# 2    Carrot
# 3      Date
# dtype: object

# %% [markdown]
# ### DataFrames
# DataFrames are two dimensional data structure that contains multiple rows and columns

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# ## Describing a DataFrame
# Pandas can be used to describe the data using various attributes and fundtions.
#
# ### Difference between Attribute and Functions
# Functions perform steps to achieve a particular goal while Attributes just display the value already stored in the Data Structure

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=303, step=1)

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.mean()
# Out:
# age          54.366337
# sex           0.683168
# cp            0.966997
# trestbps    131.623762
# chol        246.264026
# fbs           0.148515
# restecg       0.528053
# thalach     149.646865
# exang         0.326733
# oldpeak       1.039604
# slope         1.399340
# ca            0.729373
# thal          2.313531
# target        0.544554
# dtype: float64

# %% [markdown]
# ### Working with a different dataset
# This dataset is small and is added for exploratory purposes.

# %%
car_sales_df = pd.read_csv('../datasets/car-sales.csv')
car_sales_df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales_df.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
mean_distance_driven = car_sales_df['Odometer (KM)'].mean()
total_distance_driven = car_sales_df['Odometer (KM)'].sum()

# %%
print(
    'The cars have been driven an average of {} KM \nAlso, in totality all the cars have driven around {} KM'
    .format(mean_distance_driven,total_distance_driven)
)
# Out:
# The cars have been driven an average of 78601.4 KM
# Also, in totality all the cars have driven around 786014 KM

# %% [markdown]
# ## Viewing and Selecting Data

# %%
car_sales_df.tail() # Returns the bottom half of the dataset
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# **To get a specific number of rows either from the top or the bottom we can use df.head(3) or df.tail(9)**

# %% [markdown]
# ### .loc and .iloc
# These functions are used to locate the object within the table. Argument of the loc refers to the index of the object and will return the same.
# loc refers to the index while iloc refers to the actual position

# %%
# Let this be a new series
animals = pd.Series(['Lion','Tiger','Panda','Monkey','Koala'], index=[2,3,1,0,9])
print(animals)
# Out:
# 2      Lion
# 3     Tiger
# 1     Panda
# 0    Monkey
# 9     Koala
# dtype: object

# %%
# loc will refer to the index as represented below
animals.loc[1]
# Out:
# 'Panda'

# %%
# iloc will refer to the actual position of the object as represented
animals.iloc[1]
# Out:
# 'Tiger'

# %%
# If the dataframe is sorted both loc and iloc will refer to the same row
print(car_sales_df.loc[3])
print(car_sales_df.iloc[3])
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %% [markdown]
# **iloc and loc can be used for slicing too**

# %%
animals
# Out:
# 2      Lion
# 3     Tiger
# 1     Panda
# 0    Monkey
# 9     Koala
# dtype: object

# %%
print("Using loc\n{}".format(animals.loc[:3]))
print('\n')
print("Using iloc\n{}".format(animals.iloc[:3]))
# Out:
# Using loc
# 2     Lion
# 3    Tiger
# dtype: object
#
#
# Using iloc
# 2     Lion
# 3    Tiger
# 1    Panda
# dtype: object

# %%
# To select a specific column we can use the name of that column
car_sales_df['Colour']
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales_df.Colour
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %% [markdown]
# ### Boolean indexing
# when we want to use a filter on the rows that we get we do it by using boolean indexing which is as such

# %%
car_sales_df[car_sales_df["Make"] == 'Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
pd.crosstab(car_sales_df["Make"],car_sales_df['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_df.groupby("Make").mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales_df.groupby("Colour").describe()
# Out:
#        Odometer (KM)                                                           \
#                count           mean           std      min      25%       50%
# Colour
# Black            1.0   11179.000000           NaN  11179.0  11179.0   11179.0
# Blue             3.0   44328.333333  11157.729175  32549.0  39123.5   45698.0
# Green            1.0   99213.000000           NaN  99213.0  99213.0   99213.0
# Red              1.0   87899.000000           NaN  87899.0  87899.0   87899.0
# White            4.0  113684.500000  83315.222125  31600.0  52900.0  105021.5
#
#                            Doors
#              75%       max count      mean      std  min  25%  50%  75%  max
# Colour
# Black    11179.0   11179.0   1.0  5.000000      NaN  5.0  5.0  5.0  5.0  5.0
# Blue     50218.0   54738.0   3.0  3.666667  0.57735  3.0  3.5  4.0  4.0  4.0
# Green    99213.0   99213.0   1.0  4.000000      NaN  4.0  4.0  4.0  4.0  4.0
# Red      87899.0   87899.0   1.0  4.000000      NaN  4.0  4.0  4.0  4.0  4.0
# White   165806.0  213095.0   4.0  4.000000  0.00000  4.0  4.0  4.0  4.0  4.0

# %%
car_sales_df["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales_df["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_df["Price"] = car_sales_df["Price"].str.replace('[\$\,]','').astype(float)
car_sales_df
# Out:
# /var/folders/mw/y6hrwx_j2ydch6sbzcmrf6480000gn/T/ipykernel_3033/2404281331.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales_df["Price"] = car_sales_df["Price"].str.replace('[\$\,]','').astype(float)
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
# Toyota cars price compared to the kms driven
toyota_cars = car_sales_df[car_sales_df["Make"]=="Toyota"]
plt.plot(toyota_cars["Odometer (KM)"], toyota_cars["Price"])

# %% [markdown]
# ## Manipulating Data
# In this section we will demonstrate how we can manipulate the data as per our needs

# %%
# We can access the objects as string values using the .str method
car_sales_df["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales_df["Make"] = car_sales_df['Make'].str.lower()
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %% [markdown]
# ### Dealing with missing values

# %%
car_sales_missing = pd.read_csv('./../datasets/car-sales-missing-data.csv')
car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean(), inplace=True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
# inplace attribute changes the original dataFrame and there is no need to reassign the variable

car_sales_missing['Doors'].fillna(car_sales_missing['Doors'].mean(), inplace=True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    4.0      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing = pd.read_csv('./../datasets/car-sales-missing-data.csv')
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()

# %%
car_sales_missing_dropped.to_csv('car-sales-missing-dropped.csv', index=False)

# %%
car_sales_missing_dropped = None
car_sales_missing_dropped = pd.read_csv('./car-sales-missing-dropped.csv')
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2     BMW  Black   11179.0    5.0  $22,000
# 3  Nissan  White  213095.0    4.0   $3,500

# %% [markdown]
# ### Creating a custom dataframe column

# %%
seats_col = pd.Series([5,5,5,5,5,5])
car_sales_df = pd.read_csv('./../datasets/car-sales.csv')
car_sales_df['Seats'] = seats_col
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0
# 6   Honda   Blue          45698      4   $7,500.00    NaN
# 7   Honda   Blue          54738      4   $7,000.00    NaN
# 8  Toyota  White          60000      4   $6,250.00    NaN
# 9  Nissan  White          31600      4   $9,700.00    NaN

# %%
car_sales_df['Seats'].fillna(car_sales_df['Seats'].mean(), inplace=True)
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    5.0
# 1   Honda    Red          87899      4   $5,000.00    5.0
# 2  Toyota   Blue          32549      3   $7,000.00    5.0
# 3     BMW  Black          11179      5  $22,000.00    5.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0
# 8  Toyota  White          60000      4   $6,250.00    5.0
# 9  Nissan  White          31600      4   $9,700.00    5.0

# %%
# Column from Python List
fuel_economy = [3.4,5.6,7.6,8.9,6.4,2.3,2,5.6,1.2,3]
car_sales_df['fuel_economy'] = fuel_economy
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  fuel_economy
# 0  Toyota  White         150043      4   $4,000.00    5.0           3.4
# 1   Honda    Red          87899      4   $5,000.00    5.0           5.6
# 2  Toyota   Blue          32549      3   $7,000.00    5.0           7.6
# 3     BMW  Black          11179      5  $22,000.00    5.0           8.9
# 4  Nissan  White         213095      4   $3,500.00    5.0           6.4
# 5  Toyota  Green          99213      4   $4,500.00    5.0           2.3
# 6   Honda   Blue          45698      4   $7,500.00    5.0           2.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0           5.6
# 8  Toyota  White          60000      4   $6,250.00    5.0           1.2
# 9  Nissan  White          31600      4   $9,700.00    5.0           3.0

# %%
car_sales_df["fuel_used (Gallons)"] = (car_sales_df['Odometer (KM)']/100) * car_sales_df['fuel_economy']
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  fuel_economy  \
# 0  Toyota  White         150043      4   $4,000.00    5.0           3.4
# 1   Honda    Red          87899      4   $5,000.00    5.0           5.6
# 2  Toyota   Blue          32549      3   $7,000.00    5.0           7.6
# 3     BMW  Black          11179      5  $22,000.00    5.0           8.9
# 4  Nissan  White         213095      4   $3,500.00    5.0           6.4
# 5  Toyota  Green          99213      4   $4,500.00    5.0           2.3
# 6   Honda   Blue          45698      4   $7,500.00    5.0           2.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0           5.6
# 8  Toyota  White          60000      4   $6,250.00    5.0           1.2
# 9  Nissan  White          31600      4   $9,700.00    5.0           3.0
#
#    fuel_used (Gallons)  fuel_used
# 0             5101.462   5101.462
# 1             4922.344   4922.344
# 2             2473.724   2473.724
# 3              994.931    994.931
# 4            13638.080  13638.080
# 5             2281.899   2281.899
# 6              913.960    913.960
# 7             3065.328   3065.328
# 8              720.000    720.000
# 9              948.000    948.000

# %%
car_sales_df.drop("fuel_used",1, inplace=True)
car_sales_df
# Out:
# /var/folders/mw/y6hrwx_j2ydch6sbzcmrf6480000gn/T/ipykernel_3033/918922734.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   car_sales_df.drop("fuel_used",1, inplace=True)
#      Make Colour  Odometer (KM)  Doors       Price  Seats  fuel_economy  \
# 0  Toyota  White         150043      4   $4,000.00    5.0           3.4
# 1   Honda    Red          87899      4   $5,000.00    5.0           5.6
# 2  Toyota   Blue          32549      3   $7,000.00    5.0           7.6
# 3     BMW  Black          11179      5  $22,000.00    5.0           8.9
# 4  Nissan  White         213095      4   $3,500.00    5.0           6.4
# 5  Toyota  Green          99213      4   $4,500.00    5.0           2.3
# 6   Honda   Blue          45698      4   $7,500.00    5.0           2.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0           5.6
# 8  Toyota  White          60000      4   $6,250.00    5.0           1.2
# 9  Nissan  White          31600      4   $9,700.00    5.0           3.0
#
#    fuel_used (Gallons)
# 0             5101.462
# 1             4922.344
# 2             2473.724
# 3              994.931
# 4            13638.080
# 5             2281.899
# 6              913.960
# 7             3065.328
# 8              720.000
# 9              948.000

# %%
# Create a column from a single value

car_sales_df["Number_of_wheels"] = 4
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  fuel_economy  \
# 0  Toyota  White         150043      4   $4,000.00    5.0           3.4
# 1   Honda    Red          87899      4   $5,000.00    5.0           5.6
# 2  Toyota   Blue          32549      3   $7,000.00    5.0           7.6
# 3     BMW  Black          11179      5  $22,000.00    5.0           8.9
# 4  Nissan  White         213095      4   $3,500.00    5.0           6.4
# 5  Toyota  Green          99213      4   $4,500.00    5.0           2.3
# 6   Honda   Blue          45698      4   $7,500.00    5.0           2.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0           5.6
# 8  Toyota  White          60000      4   $6,250.00    5.0           1.2
# 9  Nissan  White          31600      4   $9,700.00    5.0           3.0
#
#    fuel_used (Gallons)  Number_of_wheels
# 0             5101.462                 4
# 1             4922.344                 4
# 2             2473.724                 4
# 3              994.931                 4
# 4            13638.080                 4
# 5             2281.899                 4
# 6              913.960                 4
# 7             3065.328                 4
# 8              720.000                 4
# 9              948.000                 4

# %%
car_sales_df.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer (KM)            int64
# Doors                    int64
# Price                   object
# Seats                  float64
# fuel_economy           float64
# fuel_used (Gallons)    float64
# Number_of_wheels         int64
# dtype: object

# %% [markdown]
# ### Shuffling the data
# sample method is used to shuffle the data. The frac attribute is used to decide the percentage of data that needs the shuffling (eg. 0.5 refers to 50% of the data)

# %%
car_sales_shuffled = car_sales_df.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  fuel_economy  \
# 5  Toyota  Green          99213      4   $4,500.00    5.0           2.3
# 2  Toyota   Blue          32549      3   $7,000.00    5.0           7.6
# 1   Honda    Red          87899      4   $5,000.00    5.0           5.6
# 3     BMW  Black          11179      5  $22,000.00    5.0           8.9
# 4  Nissan  White         213095      4   $3,500.00    5.0           6.4
# 8  Toyota  White          60000      4   $6,250.00    5.0           1.2
# 0  Toyota  White         150043      4   $4,000.00    5.0           3.4
# 7   Honda   Blue          54738      4   $7,000.00    5.0           5.6
# 9  Nissan  White          31600      4   $9,700.00    5.0           3.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0           2.0
#
#    fuel_used (Gallons)  Number_of_wheels
# 5             2281.899                 4
# 2             2473.724                 4
# 1             4922.344                 4
# 3              994.931                 4
# 4            13638.080                 4
# 8              720.000                 4
# 0             5101.462                 4
# 7             3065.328                 4
# 9              948.000                 4
# 6              913.960                 4

# %% [markdown]
# When working with large datasets it is a good practice to select a small amount of sample data and perform the
# operations on it. This saves time as working with the entire data can be time consuming.

# %%
car_sales_shuffled.reset_index(drop=True)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  fuel_economy  \
# 0  Toyota  Green          99213      4   $4,500.00    5.0           2.3
# 1  Toyota   Blue          32549      3   $7,000.00    5.0           7.6
# 2   Honda    Red          87899      4   $5,000.00    5.0           5.6
# 3     BMW  Black          11179      5  $22,000.00    5.0           8.9
# 4  Nissan  White         213095      4   $3,500.00    5.0           6.4
# 5  Toyota  White          60000      4   $6,250.00    5.0           1.2
# 6  Toyota  White         150043      4   $4,000.00    5.0           3.4
# 7   Honda   Blue          54738      4   $7,000.00    5.0           5.6
# 8  Nissan  White          31600      4   $9,700.00    5.0           3.0
# 9   Honda   Blue          45698      4   $7,500.00    5.0           2.0
#
#    fuel_used (Gallons)  Number_of_wheels
# 0             2281.899                 4
# 1             2473.724                 4
# 2             4922.344                 4
# 3              994.931                 4
# 4            13638.080                 4
# 5              720.000                 4
# 6             5101.462                 4
# 7             3065.328                 4
# 8              948.000                 4
# 9              913.960                 4

# %%
car_sales_df['Odometer (KM)'] = car_sales_df['Odometer (KM)'].apply(lambda x: x/1.6)

# %%
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  fuel_economy  \
# 0  Toyota  White      93776.875      4   $4,000.00    5.0           3.4
# 1   Honda    Red      54936.875      4   $5,000.00    5.0           5.6
# 2  Toyota   Blue      20343.125      3   $7,000.00    5.0           7.6
# 3     BMW  Black       6986.875      5  $22,000.00    5.0           8.9
# 4  Nissan  White     133184.375      4   $3,500.00    5.0           6.4
# 5  Toyota  Green      62008.125      4   $4,500.00    5.0           2.3
# 6   Honda   Blue      28561.250      4   $7,500.00    5.0           2.0
# 7   Honda   Blue      34211.250      4   $7,000.00    5.0           5.6
# 8  Toyota  White      37500.000      4   $6,250.00    5.0           1.2
# 9  Nissan  White      19750.000      4   $9,700.00    5.0           3.0
#
#    fuel_used (Gallons)  Number_of_wheels
# 0             5101.462                 4
# 1             4922.344                 4
# 2             2473.724                 4
# 3              994.931                 4
# 4            13638.080                 4
# 5             2281.899                 4
# 6              913.960                 4
# 7             3065.328                 4
# 8              720.000                 4
# 9              948.000                 4
